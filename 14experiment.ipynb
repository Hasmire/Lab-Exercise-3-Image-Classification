# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np

# %%
from pathlib import Path
from PIL import Image
import os

data_dir = "hair_types"
image_extensions = [".png", ".jpg"]

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]

for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        try:
            with Image.open(filepath) as img:
                img_type = img.format.lower()
                if img_type is None:
                    print(f"{filepath} is not an image")
                    os.remove(filepath)
                elif img_type not in img_type_accepted_by_tf:
                    print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
                    os.remove(filepath)

        except (IOError, OSError) as e:
            print(f"Error opening {filepath}: {e}")

# %%
from tensorflow import keras

image_size = (64, 64)
batch_size = 32

class_names = ["Curly_Hair", "Straight_Hair", "Wavy_Hair"]

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels="inferred",
    label_mode="categorical",
    class_names=class_names,
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels="inferred",
    label_mode="categorical",
    class_names=class_names,
)
# Out:
# Found 985 files belonging to 3 classes.
# Using 788 files for training.
# Found 985 files belonging to 3 classes.
# Using 197 files for validation.

# %%
class_names = train_ds.class_names
print("Class names:", class_names)
# Out:
# Class names: ['Curly_Hair', 'Straight_Hair', 'Wavy_Hair']

# %%
import matplotlib.pyplot as plt

for images, labels in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[tf.argmax(labels[i]).numpy()])
    plt.show()

# %%
data_augmentation = tf.keras.Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.2),
    ]
)

resize_and_rescale = tf.keras.Sequential(
    [layers.Resizing(64, 64), layers.Rescaling(1.0 / 255)]
)

# %%
sample_images = train_ds.take(1)
for images, _ in sample_images:
    sample_image = images[0]
    break

# Reshape the image for data augmentation
image = tf.expand_dims(sample_image, 0)
image = tf.cast(image, tf.float32)

plt.figure(figsize=(10, 10))
for i in range(9):
    augmented_image = data_augmentation(image)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(tf.squeeze(augmented_image).numpy().astype("uint8"))

plt.show()

# %%
AUTOTUNE = tf.data.AUTOTUNE


def prepare(ds, shuffle=False, augment=False):
    ds = ds.map(lambda x, y: (resize_and_rescale(x), y), num_parallel_calls=AUTOTUNE)

    if shuffle:
        ds = ds.shuffle(1000)

    if augment:
        ds = ds.map(
            lambda x, y: (data_augmentation(x, training=True), y),
            num_parallel_calls=AUTOTUNE,
        )

    # Use buffered prefetching on all datasets.
    return ds.prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, augment=True)
val_ds = prepare(val_ds)

# %%
def build_model(hp):
    inputs = tf.keras.Input(shape=(64, 64, 3))
    x = inputs

    for i in range(hp.Int("conv_layers", 1, 3, default=1)):
        x = tf.keras.layers.Conv2D(
            filters=hp.Int(f"filters_{i}", min_value=32, max_value=128, step=32),
            kernel_size=hp.Choice(f"kernel_size_{i}", values=[3, 5, 7, 9]),
            activation="relu",
            padding=hp.Choice(f"padding_{i}", values=["same", "valid"]),
            strides=hp.Choice(f"strides_{i}", values=[1, 2]),
        )(x)

        if hp.Choice("pooling" + str(i), ["max", "avg"]) == "max":
            x = tf.keras.layers.MaxPooling2D()(x)
        elif hp.get("pooling" + str(i)) == "avg":
            x = tf.keras.layers.AveragePooling2D()(x)

        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.ReLU()(x)

    if hp.Choice("global_pooling", ["max", "avg"]) == "max":
        x = tf.keras.layers.GlobalMaxPooling2D()(x)
    else:
        x = tf.keras.layers.GlobalAveragePooling2D()(x)

    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(
        128, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.001)
    )(x)

    outputs = tf.keras.layers.Dense(3, activation="softmax")(x)

    model = tf.keras.Model(inputs, outputs)

    learning_rate = hp.Choice("learning_rate", values=[1e-2, 5e-3, 1e-4])

    model.compile(
        optimizer=tf.keras.optimizers.Nadam(learning_rate=learning_rate),
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )

    return model

# %%
from keras_tuner import Hyperband
from tensorflow.keras.callbacks import EarlyStopping


tuner = Hyperband(
    hypermodel=build_model,
    objective="val_accuracy",
    max_epochs=25,
    factor=3,
    hyperband_iterations=1,
    distribution_strategy=tf.distribute.MirroredStrategy(),
    directory="my_tuning_dir",
    project_name="hair_types",
    overwrite=True,
)

tuner.search(
    train_ds,
    validation_data=val_ds,
    callbacks=[
        EarlyStopping(
            monitor="val_accuracy",
            patience=3,
            restore_best_weights=True,
        )
    ],
)
# Out:
# Trial 14 Complete [00h 01m 00s]
# val_accuracy: 0.39593908190727234
#
# Best val_accuracy So Far: 0.39593908190727234
# Total elapsed time: 00h 07m 27s
#
# Search: Running Trial #15
#
# Value             |Best Value So Far |Hyperparameter
# 2                 |1                 |conv_layers
# 96                |64                |filters_0
# 7                 |3                 |kernel_size_0
# valid             |same              |padding_0
# 1                 |1                 |strides_0
# max               |max               |pooling0
# max               |max               |global_pooling
# 0.0001            |0.005             |learning_rate
# 64                |128               |filters_1
# 9                 |3                 |kernel_size_1
# same              |valid             |padding_1
# 1                 |2                 |strides_1
# max               |avg               |pooling1
# 64                |128               |filters_2
# 7                 |9                 |kernel_size_2
# valid             |same              |padding_2
# 2                 |1                 |strides_2
# max               |avg               |pooling2
# 9                 |3                 |tuner/epochs
# 3                 |0                 |tuner/initial_epoch
# 2                 |2                 |tuner/bracket
# 1                 |0                 |tuner/round
# 0005              |None              |tuner/trial_id
#
# Epoch 4/9
# 25/25 [==============================] - 23s 789ms/step - loss: 1.0869 - accuracy: 0.4987 - val_loss: 1.1819 - val_accuracy: 0.3553
# Epoch 5/9
# 25/25 [==============================] - 19s 725ms/step - loss: 1.0665 - accuracy: 0.5178 - val_loss: 1.1785 - val_accuracy: 0.3959
# Epoch 6/9
# 16/25 [==================>...........] - ETA: 5s - loss: 1.0829 - accuracy: 0.5039
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Documents\GitHub\Lab-Exercise-3-Image-Classification\14experiment.ipynb Cell 11 line 1
#       <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> from tensorflow.keras.callbacks import EarlyStopping
#       <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> tuner = Hyperband(
#       <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a>     hypermodel=build_model,
#       <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a>     objective="val_accuracy",
#    (...)
#      <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=13'>14</a>     overwrite=True,
#      <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=14'>15</a> )
# ---> <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=16'>17</a> tuner.search(
#      <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=17'>18</a>     train_ds,
#      <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=18'>19</a>     validation_data=val_ds,
#      <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=19'>20</a>     callbacks=[
#      <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=20'>21</a>         EarlyStopping(
#      <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=21'>22</a>             monitor="val_accuracy",
#      <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=22'>23</a>             patience=3,
#      <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=23'>24</a>             restore_best_weights=True,
#      <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=24'>25</a>         )
#      <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=25'>26</a>     ],
#      <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X13sZmlsZQ%3D%3D?line=26'>27</a> )
#
# File c:\Python311\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:233, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     230         continue
#     232     self.on_trial_begin(trial)
# --> 233     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     234     self.on_trial_end(trial)
#     235 self.on_search_end()
#
# File c:\Python311\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:273, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     271 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     272     try:
# --> 273         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     274         trial.status = trial_module.TrialStatus.COMPLETED
#     275         return
#
# File c:\Python311\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:238, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     237 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 238     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     239     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     240         self.oracle.objective.name
#     241     ):
#     242         # The oracle is updated by calling `self.oracle.update_trial()` in
#     243         # `Tuner.run_trial()`. For backward compatibility, we support this
#     244         # use case. No further action needed in this case.
#     245         warnings.warn(
#     246             "The use case of calling "
#     247             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     253             stacklevel=2,
#     254         )
#
# File c:\Python311\Lib\site-packages\keras_tuner\src\tuners\hyperband.py:427, in Hyperband.run_trial(self, trial, *fit_args, **fit_kwargs)
#     425     fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     426     fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 427 return super().run_trial(trial, *fit_args, **fit_kwargs)
#
# File c:\Python311\Lib\site-packages\keras_tuner\src\engine\tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File c:\Python311\Lib\site-packages\keras_tuner\src\engine\tuner.py:233, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     231 hp = trial.hyperparameters
#     232 model = self._try_build(hp)
# --> 233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#     236 if backend.config.multi_backend():
#
# File c:\Python311\Lib\site-packages\keras_tuner\src\engine\hypermodel.py:149, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     125 def fit(self, hp, model, *args, **kwargs):
#     126     """Train the model.
#     127
#     128     Args:
#    (...)
#     147         If return a float, it should be the `objective` value.
#     148     """
# --> 149     return model.fit(*args, **kwargs)
#
# File c:\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python311\Lib\site-packages\keras\src\engine\training.py:1783, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1775 with tf.profiler.experimental.Trace(
#    1776     "train",
#    1777     epoch_num=epoch,
#    (...)
#    1780     _r=1,
#    1781 ):
#    1782     callbacks.on_train_batch_begin(step)
# -> 1783     tmp_logs = self.train_function(iterator)
#    1784     if data_handler.should_sync:
#    1785         context.async_wait()
#
# File c:\Python311\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:831, in Function.__call__(self, *args, **kwds)
#     828 compiler = "xla" if self._jit_compile else "nonXla"
#     830 with OptionalXlaContext(self._jit_compile):
# --> 831   result = self._call(*args, **kwds)
#     833 new_tracing_count = self.experimental_get_tracing_count()
#     834 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:867, in Function._call(self, *args, **kwds)
#     864   self._lock.release()
#     865   # In this case we have created variables on the first call, so we run the
#     866   # defunned version which is guaranteed to never create variables.
# --> 867   return tracing_compilation.call_function(
#     868       args, kwds, self._no_variable_creation_config
#     869   )
#     870 elif self._variable_creation_config is not None:
#     871   # Release the lock early so that multiple threads can perform the call
#     872   # in parallel.
#     873   self._lock.release()
#
# File c:\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1264, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1260 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1261 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1262     and executing_eagerly):
#    1263   # No tape is watching; skip to running the function.
# -> 1264   return self._inference_function.flat_call(args)
#    1265 forward_backward = self._select_forward_and_backward_functions(
#    1266     args,
#    1267     possible_gradient_type,
#    1268     executing_eagerly)
#    1269 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:217, in AtomicFunction.flat_call(self, args)
#     215 def flat_call(self, args: Sequence[core.Tensor]) -> Any:
#     216   """Calls with tensor inputs and returns the structured output."""
# --> 217   flat_outputs = self(*args)
#     218   return self.function_type.pack_output(flat_outputs)
#
# File c:\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:252, in AtomicFunction.__call__(self, *args)
#     250 with record.stop_recording():
#     251   if self._bound_context.executing_eagerly():
# --> 252     outputs = self._bound_context.call_function(
#     253         self.name,
#     254         list(args),
#     255         len(self.function_type.flat_outputs),
#     256     )
#     257   else:
#     258     outputs = make_call_op_in_graph(
#     259         self,
#     260         list(args),
#     261         self._bound_context.function_call_options.as_attrs(),
#     262     )
#
# File c:\Python311\Lib\site-packages\tensorflow\python\eager\context.py:1479, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1477 cancellation_context = cancellation.context()
#    1478 if cancellation_context is None:
# -> 1479   outputs = execute.execute(
#    1480       name.decode("utf-8"),
#    1481       num_outputs=num_outputs,
#    1482       inputs=tensor_inputs,
#    1483       attrs=attrs,
#    1484       ctx=self,
#    1485   )
#    1486 else:
#    1487   outputs = execute.execute_with_cancellation(
#    1488       name.decode("utf-8"),
#    1489       num_outputs=num_outputs,
#    (...)
#    1493       cancellation_manager=cancellation_context,
#    1494   )
#
# File c:\Python311\Lib\site-packages\tensorflow\python\eager\execute.py:60, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53   # Convert any objects of type core_types.Tensor to Tensor.
#      54   inputs = [
#      55       tensor_conversion_registry.convert(t)
#      56       if isinstance(t, core_types.Tensor)
#      57       else t
#      58       for t in inputs
#      59   ]
# ---> 60   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                       inputs, attrs, num_outputs)
#      62 except core._NotOkStatusException as e:
#      63   if name is not None:
#
# KeyboardInterrupt:

# %%
# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the model with the best hyperparameters and train it on the data
model = build_model(best_hps)

# %%
early_stopping = EarlyStopping(
    monitor="val_accuracy", patience=10, restore_best_weights=True, verbose=1
)

# %%
epochs = 100

history = model.fit(
    train_ds,
    epochs=epochs,
    validation_data=val_ds,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 22s 748ms/step - loss: 1.9739 - accuracy: 0.3287 - val_loss: 2.0964 - val_accuracy: 0.2843
# Epoch 2/100
# 25/25 [==============================] - 17s 668ms/step - loss: 1.2020 - accuracy: 0.3871 - val_loss: 1.4740 - val_accuracy: 0.3655
# Epoch 3/100
# 25/25 [==============================] - 17s 668ms/step - loss: 1.0938 - accuracy: 0.4987 - val_loss: 1.6255 - val_accuracy: 0.3553
# Epoch 4/100
# 25/25 [==============================] - 18s 676ms/step - loss: 1.0959 - accuracy: 0.4975 - val_loss: 1.7804 - val_accuracy: 0.3553
# Epoch 5/100
# 25/25 [==============================] - 17s 669ms/step - loss: 1.0961 - accuracy: 0.4937 - val_loss: 1.7167 - val_accuracy: 0.3756
# Epoch 6/100
# 25/25 [==============================] - 18s 694ms/step - loss: 1.0227 - accuracy: 0.5470 - val_loss: 1.1434 - val_accuracy: 0.4061
# Epoch 7/100
# 25/25 [==============================] - 19s 742ms/step - loss: 1.0856 - accuracy: 0.5038 - val_loss: 1.1877 - val_accuracy: 0.4670
# Epoch 8/100
# 25/25 [==============================] - 18s 708ms/step - loss: 1.0128 - accuracy: 0.5774 - val_loss: 1.1231 - val_accuracy: 0.4365
# Epoch 9/100
# 25/25 [==============================] - 18s 692ms/step - loss: 0.9258 - accuracy: 0.6206 - val_loss: 1.0616 - val_accuracy: 0.5127
# Epoch 10/100
# 25/25 [==============================] - 18s 697ms/step - loss: 0.8690 - accuracy: 0.6294 - val_loss: 1.1097 - val_accuracy: 0.4670
# Epoch 11/100
# 25/25 [==============================] - 18s 705ms/step - loss: 0.8090 - accuracy: 0.6675 - val_loss: 1.3116 - val_accuracy: 0.4061
# Epoch 12/100
# 25/25 [==============================] - 18s 706ms/step - loss: 0.7658 - accuracy: 0.6612 - val_loss: 1.2440 - val_accuracy: 0.5076
# Epoch 13/100
# 25/25 [==============================] - 19s 713ms/step - loss: 0.7592 - accuracy: 0.6954 - val_loss: 1.1612 - val_accuracy: 0.4619
# Epoch 14/100
# 25/25 [==============================] - 19s 710ms/step - loss: 0.6713 - accuracy: 0.7373 - val_loss: 1.1209 - val_accuracy: 0.5381
# Epoch 15/100
# 25/25 [==============================] - 19s 736ms/step - loss: 0.6345 - accuracy: 0.7563 - val_loss: 1.3610 - val_accuracy: 0.4772
# Epoch 16/100
# 25/25 [==============================] - 19s 717ms/step - loss: 0.5609 - accuracy: 0.7982 - val_loss: 1.1283 - val_accuracy: 0.5279
# Epoch 17/100
# 25/25 [==============================] - 18s 694ms/step - loss: 0.5440 - accuracy: 0.7970 - val_loss: 1.4807 - val_accuracy: 0.5228
# Epoch 18/100
# 25/25 [==============================] - 18s 710ms/step - loss: 0.5335 - accuracy: 0.8084 - val_loss: 1.3196 - val_accuracy: 0.4975
# Epoch 19/100
# 25/25 [==============================] - 19s 736ms/step - loss: 0.5059 - accuracy: 0.8223 - val_loss: 1.9916 - val_accuracy: 0.4721
# Epoch 20/100
#  4/25 [===>..........................] - ETA: 14s - loss: 0.4462 - accuracy: 0.8281
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Documents\GitHub\Lab-Exercise-3-Image-Classification\14experiment.ipynb Cell 14 line 3
#       <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> epochs = 100
# ----> <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> history = model.fit(
#       <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a>     train_ds,
#       <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a>     epochs=epochs,
#       <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a>     validation_data=val_ds,
#       <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a>     callbacks=[early_stopping],
#       <a href='vscode-notebook-cell:/d%3A/Documents/GitHub/Lab-Exercise-3-Image-Classification/14experiment.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a> )
#
# File c:\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python311\Lib\site-packages\keras\src\engine\training.py:1783, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1775 with tf.profiler.experimental.Trace(
#    1776     "train",
#    1777     epoch_num=epoch,
#    (...)
#    1780     _r=1,
#    1781 ):
#    1782     callbacks.on_train_batch_begin(step)
# -> 1783     tmp_logs = self.train_function(iterator)
#    1784     if data_handler.should_sync:
#    1785         context.async_wait()
#
# File c:\Python311\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:831, in Function.__call__(self, *args, **kwds)
#     828 compiler = "xla" if self._jit_compile else "nonXla"
#     830 with OptionalXlaContext(self._jit_compile):
# --> 831   result = self._call(*args, **kwds)
#     833 new_tracing_count = self.experimental_get_tracing_count()
#     834 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:867, in Function._call(self, *args, **kwds)
#     864   self._lock.release()
#     865   # In this case we have created variables on the first call, so we run the
#     866   # defunned version which is guaranteed to never create variables.
# --> 867   return tracing_compilation.call_function(
#     868       args, kwds, self._no_variable_creation_config
#     869   )
#     870 elif self._variable_creation_config is not None:
#     871   # Release the lock early so that multiple threads can perform the call
#     872   # in parallel.
#     873   self._lock.release()
#
# File c:\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1264, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1260 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1261 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1262     and executing_eagerly):
#    1263   # No tape is watching; skip to running the function.
# -> 1264   return self._inference_function.flat_call(args)
#    1265 forward_backward = self._select_forward_and_backward_functions(
#    1266     args,
#    1267     possible_gradient_type,
#    1268     executing_eagerly)
#    1269 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:217, in AtomicFunction.flat_call(self, args)
#     215 def flat_call(self, args: Sequence[core.Tensor]) -> Any:
#     216   """Calls with tensor inputs and returns the structured output."""
# --> 217   flat_outputs = self(*args)
#     218   return self.function_type.pack_output(flat_outputs)
#
# File c:\Python311\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:252, in AtomicFunction.__call__(self, *args)
#     250 with record.stop_recording():
#     251   if self._bound_context.executing_eagerly():
# --> 252     outputs = self._bound_context.call_function(
#     253         self.name,
#     254         list(args),
#     255         len(self.function_type.flat_outputs),
#     256     )
#     257   else:
#     258     outputs = make_call_op_in_graph(
#     259         self,
#     260         list(args),
#     261         self._bound_context.function_call_options.as_attrs(),
#     262     )
#
# File c:\Python311\Lib\site-packages\tensorflow\python\eager\context.py:1479, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1477 cancellation_context = cancellation.context()
#    1478 if cancellation_context is None:
# -> 1479   outputs = execute.execute(
#    1480       name.decode("utf-8"),
#    1481       num_outputs=num_outputs,
#    1482       inputs=tensor_inputs,
#    1483       attrs=attrs,
#    1484       ctx=self,
#    1485   )
#    1486 else:
#    1487   outputs = execute.execute_with_cancellation(
#    1488       name.decode("utf-8"),
#    1489       num_outputs=num_outputs,
#    (...)
#    1493       cancellation_manager=cancellation_context,
#    1494   )
#
# File c:\Python311\Lib\site-packages\tensorflow\python\eager\execute.py:60, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53   # Convert any objects of type core_types.Tensor to Tensor.
#      54   inputs = [
#      55       tensor_conversion_registry.convert(t)
#      56       if isinstance(t, core_types.Tensor)
#      57       else t
#      58       for t in inputs
#      59   ]
# ---> 60   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                       inputs, attrs, num_outputs)
#      62 except core._NotOkStatusException as e:
#      63   if name is not None:
#
# KeyboardInterrupt:

# %%
tf.keras.utils.plot_model(model, to_file="model_experiment14.png", show_shapes=True)

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        1792
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 64)        0
#  g2D)
#
#  batch_normalization_2 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 32, 32, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 32)        51232
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 32)          0
#  g2D)
#
#  batch_normalization_3 (Bat  (None, 8, 8, 32)          128
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 8, 8, 32)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         200832
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  batch_normalization_4 (Bat  (None, 4, 4, 128)         512
#  chNormalization)
#
#  re_lu_4 (ReLU)              (None, 4, 4, 128)         0
#
#  global_max_pooling2d_1 (Gl  (None, 128)               0
#  obalMaxPooling2D)
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 271651 (1.04 MB)
# Trainable params: 271203 (1.03 MB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %%
model.save("modelExperiment14.keras")

# %%
# Retrieve the configuration of the best hyperparameters
best_hyperparameters = best_hps.get_config()

# Print the best hyperparameters in a readable format
print("Best Hyperparameters:")
for param, value in best_hyperparameters.items():
    print(f"{param}: {value}")
# Out:
# Best Hyperparameters:
# space: [{'class_name': 'Int', 'config': {'name': 'conv_layers', 'default': 1, 'conditions': [], 'min_value': 1, 'max_value': 3, 'step': 1, 'sampling': 'linear'}}, {'class_name': 'Int', 'config': {'name': 'filters_0', 'default': None, 'conditions': [], 'min_value': 32, 'max_value': 128, 'step': 32, 'sampling': 'linear'}}, {'class_name': 'Choice', 'config': {'name': 'kernel_size_0', 'default': 3, 'conditions': [], 'values': [3, 5, 7, 9], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'padding_0', 'default': 'same', 'conditions': [], 'values': ['same', 'valid'], 'ordered': False}}, {'class_name': 'Choice', 'config': {'name': 'strides_0', 'default': 1, 'conditions': [], 'values': [1, 2], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'pooling0', 'default': 'max', 'conditions': [], 'values': ['max', 'avg'], 'ordered': False}}, {'class_name': 'Choice', 'config': {'name': 'global_pooling', 'default': 'max', 'conditions': [], 'values': ['max', 'avg'], 'ordered': False}}, {'class_name': 'Choice', 'config': {'name': 'learning_rate', 'default': 0.01, 'conditions': [], 'values': [0.01, 0.005, 0.0001], 'ordered': True}}, {'class_name': 'Int', 'config': {'name': 'filters_1', 'default': None, 'conditions': [], 'min_value': 32, 'max_value': 128, 'step': 32, 'sampling': 'linear'}}, {'class_name': 'Choice', 'config': {'name': 'kernel_size_1', 'default': 3, 'conditions': [], 'values': [3, 5, 7, 9], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'padding_1', 'default': 'same', 'conditions': [], 'values': ['same', 'valid'], 'ordered': False}}, {'class_name': 'Choice', 'config': {'name': 'strides_1', 'default': 1, 'conditions': [], 'values': [1, 2], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'pooling1', 'default': 'max', 'conditions': [], 'values': ['max', 'avg'], 'ordered': False}}, {'class_name': 'Int', 'config': {'name': 'filters_2', 'default': None, 'conditions': [], 'min_value': 32, 'max_value': 128, 'step': 32, 'sampling': 'linear'}}, {'class_name': 'Choice', 'config': {'name': 'kernel_size_2', 'default': 3, 'conditions': [], 'values': [3, 5, 7, 9], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'padding_2', 'default': 'same', 'conditions': [], 'values': ['same', 'valid'], 'ordered': False}}, {'class_name': 'Choice', 'config': {'name': 'strides_2', 'default': 1, 'conditions': [], 'values': [1, 2], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'pooling2', 'default': 'max', 'conditions': [], 'values': ['max', 'avg'], 'ordered': False}}]
# values: {'conv_layers': 3, 'filters_0': 64, 'kernel_size_0': 3, 'padding_0': 'same', 'strides_0': 1, 'pooling0': 'max', 'global_pooling': 'max', 'learning_rate': 0.005, 'filters_1': 32, 'kernel_size_1': 5, 'padding_1': 'same', 'strides_1': 2, 'pooling1': 'max', 'filters_2': 128, 'kernel_size_2': 7, 'padding_2': 'same', 'strides_2': 1, 'pooling2': 'max', 'tuner/epochs': 25, 'tuner/initial_epoch': 9, 'tuner/bracket': 2, 'tuner/round': 2, 'tuner/trial_id': '0013'}

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

loss = history.history["loss"]
val_loss = history.history["val_loss"]

best_epoch = np.argmax(val_acc)

epochs_range = range(len(acc))

plt.figure(figsize=(12, 6))

# Plotting Training and Validation Accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Training Accuracy")
plt.plot(epochs_range, val_acc, label="Validation Accuracy")
plt.scatter(best_epoch, acc[best_epoch], color="red")
plt.scatter(best_epoch, val_acc[best_epoch], color="red", label="Best Epoch")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(loc="lower right")
plt.title("Training and Validation Accuracy")
plt.grid(True)

# Plotting Training and Validation Loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label="Validation Loss")
plt.scatter(best_epoch, loss[best_epoch], color="red")
plt.scatter(best_epoch, val_loss[best_epoch], color="red", label="Best Epoch")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc="upper right")
plt.title("Training and Validation Loss")
plt.grid(True)

plt.suptitle("Training and Validation Metrics", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
print(f"Best Epoch: {best_epoch + 1}")
print(f"Accuracy at Best Epoch: {acc[best_epoch]:.4f}")
print(f"Validation Accuracy at Best Epoch: {val_acc[best_epoch]:.4f}")
print(f"Loss at Best Epoch: {loss[best_epoch]:.4f}")
print(f"Validation Loss at Best Epoch: {val_loss[best_epoch]:.4f}")
# Out:
# Best Epoch: 13
# Accuracy at Best Epoch: 0.9772
# Validation Accuracy at Best Epoch: 0.6041
# Loss at Best Epoch: 0.1637
# Validation Loss at Best Epoch: 1.0033

# %%
img = keras.preprocessing.image.load_img(
    "hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--layered-natural-hair-natural-black-hairstyles.jpg",
    target_size=image_size,
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
print(
    "This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions[0])
)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# This image is 0.00 percent curly hair, 1.00 percent straight hair, and 0.00 percent wavy hair.
