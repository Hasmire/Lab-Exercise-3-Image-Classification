# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np

# %%
from pathlib import Path
from PIL import Image
import os

data_dir = "hair_types"
image_extensions = [".png", ".jpg"]

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]

for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        try:
            with Image.open(filepath) as img:
                img_type = img.format.lower()
                if img_type is None:
                    print(f"{filepath} is not an image")
                    os.remove(filepath)
                elif img_type not in img_type_accepted_by_tf:
                    print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
                    os.remove(filepath)

        except (IOError, OSError) as e:
            print(f"Error opening {filepath}: {e}")

# %%
from tensorflow import keras

image_size = (64, 64)
batch_size = 32

class_names = ["Curly_Hair", "Straight_Hair", "Wavy_Hair"]

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels="inferred",
    label_mode="categorical",
    class_names=class_names,
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels="inferred",
    label_mode="categorical",
    class_names=class_names,
)
# Out:
# Found 985 files belonging to 3 classes.
# Using 788 files for training.
# Found 985 files belonging to 3 classes.
# Using 197 files for validation.

# %%
class_names = train_ds.class_names
print("Class names:", class_names)
# Out:
# Class names: ['Curly_Hair', 'Straight_Hair', 'Wavy_Hair']

# %%
import matplotlib.pyplot as plt

for images, labels in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[tf.argmax(labels[i]).numpy()])
    plt.show()

# %%
data_augmentation = tf.keras.Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical", input_shape=(64, 64, 3)),
        layers.RandomRotation(factor=0.4),
    ]
)

resize_and_rescale = tf.keras.Sequential(
    [layers.Resizing(64, 64), layers.Rescaling(1.0 / 255)]
)

# %%
sample_images = train_ds.take(1)
for images, _ in sample_images:
    sample_image = images[0]
    break

# Reshape the image for data augmentation
image = tf.expand_dims(sample_image, 0)
image = tf.cast(image, tf.float32)

plt.figure(figsize=(10, 10))
for i in range(9):
    augmented_image = data_augmentation(image)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(tf.squeeze(augmented_image).numpy().astype("uint8"))

plt.show()

# %%
AUTOTUNE = tf.data.AUTOTUNE


def prepare(ds, shuffle=False, augment=False):
    ds = ds.map(lambda x, y: (resize_and_rescale(x), y), num_parallel_calls=AUTOTUNE)

    if shuffle:
        ds = ds.shuffle(1000)

    if augment:
        ds = ds.map(
            lambda x, y: (data_augmentation(x, training=True), y),
            num_parallel_calls=AUTOTUNE,
        )

    # Use buffered prefetching on all datasets.
    return ds.prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds)
val_ds = prepare(val_ds)

# %%
def build_model(hp):
    inputs = tf.keras.Input(shape=(64, 64, 3))
    x = inputs

    for i in range(hp.Int("conv_layers", 1, 5, default=3)):
        x = tf.keras.layers.Conv2D(
            filters=hp.Int(f"filters_{i}", min_value=32, max_value=160, step=32),
            kernel_size=hp.Choice(f"kernel_size_{i}", values=[3, 5]),
            activation="relu",
            padding="same",
            strides=1,
        )(x)

        if hp.Choice("pooling" + str(i), ["max", "avg"]) == "max":
            x = tf.keras.layers.MaxPooling2D()(x)
        else:
            x = tf.keras.layers.AveragePooling2D()(x)

        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Dropout(0.2)(x)
        x = tf.keras.layers.ReLU()(x)

    if hp.Choice("global_pooling", ["max", "avg"]) == "max":
        x = tf.keras.layers.GlobalMaxPooling2D()(x)
    else:
        x = tf.keras.layers.GlobalAveragePooling2D()(x)

    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(64, activation="relu")(x)
    x = tf.keras.layers.Dense(32, activation="relu")(x)

    outputs = tf.keras.layers.Dense(3, activation="softmax")(x)

    model = tf.keras.Model(inputs, outputs)

    learning_rate = hp.Choice("learning_rate", values=[1e-2, 1e-3, 1e-4])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )

    return model

# %%
from keras_tuner import Hyperband
from tensorflow.keras.callbacks import EarlyStopping

tuner = Hyperband(
    hypermodel=build_model,
    objective="val_accuracy",
    max_epochs=10,
    factor=5,
    hyperband_iterations=1,
    distribution_strategy=tf.distribute.MirroredStrategy(),
    directory="my_tuning_dir",
    project_name="hair_types",
    overwrite=True,
)

tuner.search(
    train_ds,
    validation_data=val_ds,
    callbacks=[tf.keras.callbacks.EarlyStopping("val_accuracy")],
)
# Out:
# Trial 13 Complete [00h 00m 19s]
# val_accuracy: 0.3553299605846405
#
# Best val_accuracy So Far: 0.39086294174194336
# Total elapsed time: 00h 06m 12s

# %%
# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the model with the best hyperparameters and train it on the data
model = build_model(best_hps)

# %%
early_stopping = EarlyStopping(
    monitor="val_accuracy", patience=10, restore_best_weights=True, verbose=1
)

# %%
epochs = 100

history = model.fit(
    train_ds,
    epochs=epochs,
    validation_data=val_ds,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 16s 532ms/step - loss: 1.0844 - accuracy: 0.4239 - val_loss: 37.8799 - val_accuracy: 0.2843
# Epoch 2/100
# 25/25 [==============================] - 13s 497ms/step - loss: 0.9398 - accuracy: 0.5292 - val_loss: 32.7810 - val_accuracy: 0.2843
# Epoch 3/100
# 25/25 [==============================] - 13s 495ms/step - loss: 0.8707 - accuracy: 0.5673 - val_loss: 20.0091 - val_accuracy: 0.2843
# Epoch 4/100
# 25/25 [==============================] - 13s 496ms/step - loss: 0.8358 - accuracy: 0.5964 - val_loss: 1.5260 - val_accuracy: 0.3452
# Epoch 5/100
# 25/25 [==============================] - 13s 493ms/step - loss: 0.8118 - accuracy: 0.6168 - val_loss: 1.9402 - val_accuracy: 0.3553
# Epoch 6/100
# 25/25 [==============================] - 13s 494ms/step - loss: 0.7346 - accuracy: 0.6713 - val_loss: 2.0300 - val_accuracy: 0.3655
# Epoch 7/100
# 25/25 [==============================] - 13s 496ms/step - loss: 0.7005 - accuracy: 0.6878 - val_loss: 2.6680 - val_accuracy: 0.3350
# Epoch 8/100
# 25/25 [==============================] - 13s 494ms/step - loss: 0.6625 - accuracy: 0.6980 - val_loss: 3.7171 - val_accuracy: 0.2944
# Epoch 9/100
# 25/25 [==============================] - 13s 493ms/step - loss: 0.6888 - accuracy: 0.6904 - val_loss: 3.7103 - val_accuracy: 0.4365
# Epoch 10/100
# 25/25 [==============================] - 13s 498ms/step - loss: 0.6696 - accuracy: 0.7094 - val_loss: 1.9135 - val_accuracy: 0.3756
# Epoch 11/100
# 25/25 [==============================] - 13s 499ms/step - loss: 0.6078 - accuracy: 0.7424 - val_loss: 7.1004 - val_accuracy: 0.2843
# Epoch 12/100
# 25/25 [==============================] - 13s 496ms/step - loss: 0.5288 - accuracy: 0.7944 - val_loss: 1.8859 - val_accuracy: 0.3858
# Epoch 13/100
# 25/25 [==============================] - 13s 498ms/step - loss: 0.4978 - accuracy: 0.7919 - val_loss: 2.0944 - val_accuracy: 0.3959
# Epoch 14/100
# 25/25 [==============================] - 13s 498ms/step - loss: 0.4266 - accuracy: 0.8376 - val_loss: 1.3078 - val_accuracy: 0.4670
# Epoch 15/100
# 25/25 [==============================] - 13s 496ms/step - loss: 0.4653 - accuracy: 0.8135 - val_loss: 2.2225 - val_accuracy: 0.4264
# Epoch 16/100
# 25/25 [==============================] - 13s 495ms/step - loss: 0.4075 - accuracy: 0.8376 - val_loss: 1.8729 - val_accuracy: 0.4924
# Epoch 17/100
# 25/25 [==============================] - 13s 498ms/step - loss: 0.4041 - accuracy: 0.8401 - val_loss: 2.3626 - val_accuracy: 0.4518
# Epoch 18/100
# 25/25 [==============================] - 13s 494ms/step - loss: 0.3538 - accuracy: 0.8617 - val_loss: 1.0418 - val_accuracy: 0.6345
# Epoch 19/100
# 25/25 [==============================] - 13s 496ms/step - loss: 0.2775 - accuracy: 0.9023 - val_loss: 1.6108 - val_accuracy: 0.5076
# Epoch 20/100
# 25/25 [==============================] - 13s 499ms/step - loss: 0.3234 - accuracy: 0.8706 - val_loss: 1.2950 - val_accuracy: 0.5736
# Epoch 21/100
# 25/25 [==============================] - 13s 495ms/step - loss: 0.2839 - accuracy: 0.8985 - val_loss: 1.7331 - val_accuracy: 0.4924
# Epoch 22/100
# 25/25 [==============================] - 13s 495ms/step - loss: 0.2625 - accuracy: 0.8921 - val_loss: 1.2481 - val_accuracy: 0.5736
# Epoch 23/100
# 25/25 [==============================] - 13s 492ms/step - loss: 0.2896 - accuracy: 0.8756 - val_loss: 2.4714 - val_accuracy: 0.4315
# Epoch 24/100
# 25/25 [==============================] - 13s 498ms/step - loss: 0.2907 - accuracy: 0.8883 - val_loss: 1.9222 - val_accuracy: 0.5178
# Epoch 25/100
# 25/25 [==============================] - 13s 496ms/step - loss: 0.2787 - accuracy: 0.8921 - val_loss: 1.3184 - val_accuracy: 0.6142
# Epoch 26/100
# 25/25 [==============================] - 13s 494ms/step - loss: 0.2586 - accuracy: 0.9010 - val_loss: 1.1503 - val_accuracy: 0.5838
# Epoch 27/100
# 25/25 [==============================] - 13s 495ms/step - loss: 0.1924 - accuracy: 0.9239 - val_loss: 2.7644 - val_accuracy: 0.4721
# Epoch 28/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1732 - accuracy: 0.9416Restoring model weights from the end of the best epoch: 18.
# 25/25 [==============================] - 13s 494ms/step - loss: 0.1732 - accuracy: 0.9416 - val_loss: 1.2509 - val_accuracy: 0.6244
# Epoch 28: early stopping

# %%
tf.keras.utils.plot_model(model, to_file="model_final.png", show_shapes=True)

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 160)       4480
#
#  max_pooling2d_3 (MaxPoolin  (None, 32, 32, 160)       0
#  g2D)
#
#  batch_normalization_3 (Bat  (None, 32, 32, 160)       640
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 32, 32, 160)       0
#
#  re_lu_3 (ReLU)              (None, 32, 32, 160)       0
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 160)       230560
#
#  max_pooling2d_4 (MaxPoolin  (None, 16, 16, 160)       0
#  g2D)
#
#  batch_normalization_4 (Bat  (None, 16, 16, 160)       640
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 16, 16, 160)       0
#
#  re_lu_4 (ReLU)              (None, 16, 16, 160)       0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)        92224
#
#  max_pooling2d_5 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  batch_normalization_5 (Bat  (None, 8, 8, 64)          256
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 8, 8, 64)          0
#
#  re_lu_5 (ReLU)              (None, 8, 8, 64)          0
#
#  global_average_pooling2d (  (None, 64)                0
#  GlobalAveragePooling2D)
#
#  flatten_1 (Flatten)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 335139 (1.28 MB)
# Trainable params: 334371 (1.28 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %%
model.save("modelFinal.keras")

# %%
# Retrieve the configuration of the best hyperparameters
best_hyperparameters = best_hps.get_config()

# Print the best hyperparameters in a readable format
print("Best Hyperparameters:")
for param, value in best_hyperparameters.items():
    print(f"{param}: {value}")
# Out:
# Best Hyperparameters:
# space: [{'class_name': 'Int', 'config': {'name': 'conv_layers', 'default': 3, 'conditions': [], 'min_value': 1, 'max_value': 5, 'step': 1, 'sampling': 'linear'}}, {'class_name': 'Int', 'config': {'name': 'filters_0', 'default': None, 'conditions': [], 'min_value': 32, 'max_value': 160, 'step': 32, 'sampling': 'linear'}}, {'class_name': 'Choice', 'config': {'name': 'kernel_size_0', 'default': 3, 'conditions': [], 'values': [3, 5], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'pooling0', 'default': 'max', 'conditions': [], 'values': ['max', 'avg'], 'ordered': False}}, {'class_name': 'Int', 'config': {'name': 'filters_1', 'default': None, 'conditions': [], 'min_value': 32, 'max_value': 160, 'step': 32, 'sampling': 'linear'}}, {'class_name': 'Choice', 'config': {'name': 'kernel_size_1', 'default': 3, 'conditions': [], 'values': [3, 5], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'pooling1', 'default': 'max', 'conditions': [], 'values': ['max', 'avg'], 'ordered': False}}, {'class_name': 'Int', 'config': {'name': 'filters_2', 'default': None, 'conditions': [], 'min_value': 32, 'max_value': 160, 'step': 32, 'sampling': 'linear'}}, {'class_name': 'Choice', 'config': {'name': 'kernel_size_2', 'default': 3, 'conditions': [], 'values': [3, 5], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'pooling2', 'default': 'max', 'conditions': [], 'values': ['max', 'avg'], 'ordered': False}}, {'class_name': 'Choice', 'config': {'name': 'global_pooling', 'default': 'max', 'conditions': [], 'values': ['max', 'avg'], 'ordered': False}}, {'class_name': 'Choice', 'config': {'name': 'learning_rate', 'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}}, {'class_name': 'Int', 'config': {'name': 'filters_3', 'default': None, 'conditions': [], 'min_value': 32, 'max_value': 160, 'step': 32, 'sampling': 'linear'}}, {'class_name': 'Choice', 'config': {'name': 'kernel_size_3', 'default': 3, 'conditions': [], 'values': [3, 5], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'pooling3', 'default': 'max', 'conditions': [], 'values': ['max', 'avg'], 'ordered': False}}]
# values: {'conv_layers': 3, 'filters_0': 160, 'kernel_size_0': 3, 'pooling0': 'max', 'filters_1': 160, 'kernel_size_1': 3, 'pooling1': 'max', 'filters_2': 64, 'kernel_size_2': 3, 'pooling2': 'max', 'global_pooling': 'avg', 'learning_rate': 0.01, 'filters_3': 32, 'kernel_size_3': 3, 'pooling3': 'max', 'tuner/epochs': 2, 'tuner/initial_epoch': 0, 'tuner/bracket': 1, 'tuner/round': 0}

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

loss = history.history["loss"]
val_loss = history.history["val_loss"]

best_epoch = np.argmax(val_acc)

epochs_range = range(len(acc))

plt.figure(figsize=(12, 6))

# Plotting Training and Validation Accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Training Accuracy")
plt.plot(epochs_range, val_acc, label="Validation Accuracy")
plt.scatter(best_epoch, acc[best_epoch], color="red")
plt.scatter(best_epoch, val_acc[best_epoch], color="red", label="Best Epoch")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(loc="lower right")
plt.title("Training and Validation Accuracy")
plt.grid(True)

# Plotting Training and Validation Loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label="Validation Loss")
plt.scatter(best_epoch, loss[best_epoch], color="red")
plt.scatter(best_epoch, val_loss[best_epoch], color="red", label="Best Epoch")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc="upper right")
plt.title("Training and Validation Loss")
plt.grid(True)

plt.suptitle("Training and Validation Metrics", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
print(f"Best Epoch: {best_epoch + 1}")
print(f"Accuracy at Best Epoch: {acc[best_epoch]:.4f}")
print(f"Validation Accuracy at Best Epoch: {val_acc[best_epoch]:.4f}")
print(f"Loss at Best Epoch: {loss[best_epoch]:.4f}")
print(f"Validation Loss at Best Epoch: {val_loss[best_epoch]:.4f}")
# Out:
# Best Epoch: 18
# Accuracy at Best Epoch: 0.8617
# Validation Accuracy at Best Epoch: 0.6345
# Loss at Best Epoch: 0.3538
# Validation Loss at Best Epoch: 1.0418

# %%
img = keras.preprocessing.image.load_img(
    "hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--layered-natural-hair-natural-black-hairstyles.jpg",
    target_size=image_size,
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
print(
    "This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions[0])
)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# This image is 1.00 percent curly hair, 0.00 percent straight hair, and 0.00 percent wavy hair.
