# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np

# %%
from pathlib import Path
from PIL import Image
import os

data_dir = "hair_types"
image_extensions = [".png", ".jpg"]

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]

for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        try:
            with Image.open(filepath) as img:
                img_type = img.format.lower()
                if img_type is None:
                    print(f"{filepath} is not an image")
                    os.remove(filepath)
                elif img_type not in img_type_accepted_by_tf:
                    print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
                    os.remove(filepath)

        except (IOError, OSError) as e:
            print(f"Error opening {filepath}: {e}")

# %%
from tensorflow import keras

image_size = (64, 64)
batch_size = 32

class_names = ["Curly_Hair", "Straight_Hair", "Wavy_Hair"]

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels="inferred",
    label_mode="categorical",
    class_names=class_names,
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels="inferred",
    label_mode="categorical",
    class_names=class_names,
)
# Out:
# Found 985 files belonging to 3 classes.
# Using 788 files for training.
# Found 985 files belonging to 3 classes.
# Using 197 files for validation.

# %%
class_names = train_ds.class_names
print("Class names:", class_names)
# Out:
# Class names: ['Curly_Hair', 'Straight_Hair', 'Wavy_Hair']

# %%
import matplotlib.pyplot as plt

for images, labels in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[tf.argmax(labels[i]).numpy()])
    plt.show()

# %%
data_augmentation = tf.keras.Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.2),
    ]
)

resize_and_rescale = tf.keras.Sequential(
    [layers.Resizing(64, 64), layers.Rescaling(1.0 / 255)]
)

# %%
sample_images = train_ds.take(1)
for images, _ in sample_images:
    sample_image = images[0]
    break

# Reshape the image for data augmentation
image = tf.expand_dims(sample_image, 0)
image = tf.cast(image, tf.float32)

plt.figure(figsize=(10, 10))
for i in range(9):
    augmented_image = data_augmentation(image)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(tf.squeeze(augmented_image).numpy().astype("uint8"))

plt.show()

# %%
AUTOTUNE = tf.data.AUTOTUNE


def prepare(ds, shuffle=False, augment=False):
    ds = ds.map(lambda x, y: (resize_and_rescale(x), y), num_parallel_calls=AUTOTUNE)

    if shuffle:
        ds = ds.shuffle(1000)

    if augment:
        ds = ds.map(
            lambda x, y: (data_augmentation(x, training=True), y),
            num_parallel_calls=AUTOTUNE,
        )

    # Use buffered prefetching on all datasets.
    return ds.prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds, augment=True)
val_ds = prepare(val_ds)

# %%
# Define a function to build your model
def build_model(hp):
    inputs = tf.keras.Input(shape=(64, 64, 3))
    # x = data_augmentation(inputs)
    x = inputs

    for i in range(hp.Int("conv_layers", 1, 5, default=3)):
        x = tf.keras.layers.Conv2D(
            filters=hp.Int(f"filters_{i}", min_value=32, max_value=160, step=32),
            kernel_size=hp.Choice(f"kernel_size_{i}", values=[3, 5]),
            activation="relu",
            padding="same",
            strides=1,
        )(x)

        if hp.Choice("pooling" + str(i), ["max", "avg"]) == "max":
            x = tf.keras.layers.MaxPooling2D()(x)
        else:
            x = tf.keras.layers.AveragePooling2D()(x)

        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Dropout(0.2)(x)
        x = tf.keras.layers.ReLU()(x)

    if hp.Choice("global_pooling", ["max", "avg"]) == "max":
        x = tf.keras.layers.GlobalMaxPooling2D()(x)
    else:
        x = tf.keras.layers.GlobalAveragePooling2D()(x)

    x = tf.keras.layers.Dense(64, activation="relu")(x)
    x = tf.keras.layers.Dense(32, activation="relu")(x)

    outputs = tf.keras.layers.Dense(3, activation="softmax")(x)

    model = tf.keras.Model(inputs, outputs)

    learning_rate = hp.Choice("learning_rate", values=[1e-2, 1e-3, 1e-4])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )

    return model

# %%
from keras_tuner import Hyperband
from tensorflow.keras.callbacks import EarlyStopping


tuner = Hyperband(
    hypermodel=build_model,
    objective="val_accuracy",
    max_epochs=10,
    factor=5,
    hyperband_iterations=1,
    distribution_strategy=tf.distribute.MirroredStrategy(),
    directory="my_tuning_dir",
    project_name="hair_types",
    overwrite=True,
)

tuner.search(
    train_ds,
    validation_data=val_ds,
    callbacks=[tf.keras.callbacks.EarlyStopping("val_accuracy")],
)
# Out:
# Trial 13 Complete [00h 00m 21s]
# val_accuracy: 0.3756345212459564
#
# Best val_accuracy So Far: 0.3756345212459564
# Total elapsed time: 00h 05m 30s

# %%
# Get the best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the model with the best hyperparameters and train it on the data
model = build_model(best_hps)

# %%
early_stopping = EarlyStopping(
    monitor="val_accuracy", patience=10, restore_best_weights=True, verbose=1
)

# %%
epochs = 100

history = model.fit(
    train_ds,
    epochs=epochs,
    validation_data=val_ds,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 11s 285ms/step - loss: 1.2482 - accuracy: 0.3388 - val_loss: 16.4149 - val_accuracy: 0.3553
# Epoch 2/100
# 25/25 [==============================] - 8s 305ms/step - loss: 1.1051 - accuracy: 0.3338 - val_loss: 1.1000 - val_accuracy: 0.2843
# Epoch 3/100
# 25/25 [==============================] - 8s 279ms/step - loss: 1.0945 - accuracy: 0.3883 - val_loss: 1.1045 - val_accuracy: 0.2843
# Epoch 4/100
# 25/25 [==============================] - 8s 278ms/step - loss: 1.0898 - accuracy: 0.3997 - val_loss: 1.1076 - val_accuracy: 0.2843
# Epoch 5/100
# 25/25 [==============================] - 8s 272ms/step - loss: 1.0852 - accuracy: 0.3909 - val_loss: 1.1189 - val_accuracy: 0.2843
# Epoch 6/100
# 25/25 [==============================] - 7s 261ms/step - loss: 1.0741 - accuracy: 0.4226 - val_loss: 1.1077 - val_accuracy: 0.2843
# Epoch 7/100
# 25/25 [==============================] - 7s 263ms/step - loss: 1.0587 - accuracy: 0.4201 - val_loss: 1.2795 - val_accuracy: 0.2843
# Epoch 8/100
# 25/25 [==============================] - 7s 262ms/step - loss: 1.0306 - accuracy: 0.4467 - val_loss: 1.3501 - val_accuracy: 0.3096
# Epoch 9/100
# 25/25 [==============================] - 7s 265ms/step - loss: 1.0313 - accuracy: 0.4746 - val_loss: 1.3257 - val_accuracy: 0.2690
# Epoch 10/100
# 25/25 [==============================] - 7s 268ms/step - loss: 1.0081 - accuracy: 0.5216 - val_loss: 1.7312 - val_accuracy: 0.3096
# Epoch 11/100
# 25/25 [==============================] - 7s 265ms/step - loss: 0.9692 - accuracy: 0.5241 - val_loss: 1.0514 - val_accuracy: 0.4365
# Epoch 12/100
# 25/25 [==============================] - 7s 261ms/step - loss: 0.9756 - accuracy: 0.5228 - val_loss: 1.1325 - val_accuracy: 0.3350
# Epoch 13/100
# 25/25 [==============================] - 7s 261ms/step - loss: 1.0018 - accuracy: 0.5190 - val_loss: 2.2372 - val_accuracy: 0.2843
# Epoch 14/100
# 25/25 [==============================] - 7s 261ms/step - loss: 0.9535 - accuracy: 0.5431 - val_loss: 1.8944 - val_accuracy: 0.3401
# Epoch 15/100
# 25/25 [==============================] - 7s 260ms/step - loss: 0.9717 - accuracy: 0.5216 - val_loss: 1.0651 - val_accuracy: 0.3909
# Epoch 16/100
# 25/25 [==============================] - 7s 263ms/step - loss: 0.9506 - accuracy: 0.5495 - val_loss: 1.2437 - val_accuracy: 0.3350
# Epoch 17/100
# 25/25 [==============================] - 7s 258ms/step - loss: 0.9338 - accuracy: 0.5558 - val_loss: 1.2778 - val_accuracy: 0.3756
# Epoch 18/100
# 25/25 [==============================] - 7s 264ms/step - loss: 0.9378 - accuracy: 0.5482 - val_loss: 1.1189 - val_accuracy: 0.3909
# Epoch 19/100
# 25/25 [==============================] - 7s 261ms/step - loss: 0.9469 - accuracy: 0.5305 - val_loss: 1.0692 - val_accuracy: 0.4315
# Epoch 20/100
# 25/25 [==============================] - 7s 266ms/step - loss: 0.9249 - accuracy: 0.5698 - val_loss: 1.0294 - val_accuracy: 0.5076
# Epoch 21/100
# 25/25 [==============================] - 7s 264ms/step - loss: 0.9123 - accuracy: 0.5749 - val_loss: 1.1648 - val_accuracy: 0.3299
# Epoch 22/100
# 25/25 [==============================] - 7s 261ms/step - loss: 0.9530 - accuracy: 0.5482 - val_loss: 1.0308 - val_accuracy: 0.5127
# Epoch 23/100
# 25/25 [==============================] - 7s 256ms/step - loss: 0.9274 - accuracy: 0.5317 - val_loss: 1.0173 - val_accuracy: 0.4670
# Epoch 24/100
# 25/25 [==============================] - 7s 259ms/step - loss: 0.9055 - accuracy: 0.5622 - val_loss: 0.9634 - val_accuracy: 0.5228
# Epoch 25/100
# 25/25 [==============================] - 7s 258ms/step - loss: 0.9173 - accuracy: 0.5508 - val_loss: 0.9901 - val_accuracy: 0.5076
# Epoch 26/100
# 25/25 [==============================] - 7s 260ms/step - loss: 0.8811 - accuracy: 0.5787 - val_loss: 1.1302 - val_accuracy: 0.4162
# Epoch 27/100
# 25/25 [==============================] - 7s 258ms/step - loss: 0.9123 - accuracy: 0.5596 - val_loss: 1.1615 - val_accuracy: 0.3959
# Epoch 28/100
# 25/25 [==============================] - 7s 259ms/step - loss: 0.9017 - accuracy: 0.5647 - val_loss: 1.3353 - val_accuracy: 0.3706
# Epoch 29/100
# 25/25 [==============================] - 7s 260ms/step - loss: 0.9046 - accuracy: 0.5749 - val_loss: 1.0194 - val_accuracy: 0.5533
# Epoch 30/100
# 25/25 [==============================] - 7s 259ms/step - loss: 0.8918 - accuracy: 0.5888 - val_loss: 1.1387 - val_accuracy: 0.4162
# Epoch 31/100
# 25/25 [==============================] - 7s 259ms/step - loss: 0.8855 - accuracy: 0.5926 - val_loss: 1.4408 - val_accuracy: 0.3655
# Epoch 32/100
# 25/25 [==============================] - 7s 255ms/step - loss: 0.8918 - accuracy: 0.5635 - val_loss: 1.1534 - val_accuracy: 0.4467
# Epoch 33/100
# 25/25 [==============================] - 7s 257ms/step - loss: 0.8926 - accuracy: 0.5787 - val_loss: 0.9729 - val_accuracy: 0.5431
# Epoch 34/100
# 25/25 [==============================] - 7s 258ms/step - loss: 0.8794 - accuracy: 0.5876 - val_loss: 1.0281 - val_accuracy: 0.5076
# Epoch 35/100
# 25/25 [==============================] - 7s 271ms/step - loss: 0.8831 - accuracy: 0.5876 - val_loss: 0.9999 - val_accuracy: 0.5076
# Epoch 36/100
# 25/25 [==============================] - 7s 259ms/step - loss: 0.8661 - accuracy: 0.5914 - val_loss: 1.0965 - val_accuracy: 0.4010
# Epoch 37/100
# 25/25 [==============================] - 7s 259ms/step - loss: 0.8924 - accuracy: 0.5596 - val_loss: 1.1691 - val_accuracy: 0.4061
# Epoch 38/100
# 25/25 [==============================] - 8s 283ms/step - loss: 0.8612 - accuracy: 0.5926 - val_loss: 1.0050 - val_accuracy: 0.4670
# Epoch 39/100
# 25/25 [==============================] - ETA: 0s - loss: 0.8737 - accuracy: 0.5825Restoring model weights from the end of the best epoch: 29.
# 25/25 [==============================] - 7s 259ms/step - loss: 0.8737 - accuracy: 0.5825 - val_loss: 1.0303 - val_accuracy: 0.4975
# Epoch 39: early stopping

# %%
tf.keras.utils.plot_model(model, to_file="model_experiment11.png", show_shapes=True)

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 96)        7296
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 96)        0
#  g2D)
#
#  batch_normalization_5 (Bat  (None, 32, 32, 96)        384
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 32, 32, 96)        0
#
#  re_lu_5 (ReLU)              (None, 32, 32, 96)        0
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        27680
#
#  average_pooling2d_3 (Avera  (None, 16, 16, 32)        0
#  gePooling2D)
#
#  batch_normalization_6 (Bat  (None, 16, 16, 32)        128
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 16, 16, 32)        0
#
#  re_lu_6 (ReLU)              (None, 16, 16, 32)        0
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 160)       46240
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 160)         0
#  g2D)
#
#  batch_normalization_7 (Bat  (None, 8, 8, 160)         640
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 8, 8, 160)         0
#
#  re_lu_7 (ReLU)              (None, 8, 8, 160)         0
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 160)         230560
#
#  average_pooling2d_4 (Avera  (None, 4, 4, 160)         0
#  gePooling2D)
#
#  batch_normalization_8 (Bat  (None, 4, 4, 160)         640
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 4, 4, 160)         0
#
#  re_lu_8 (ReLU)              (None, 4, 4, 160)         0
#
#  conv2d_9 (Conv2D)           (None, 4, 4, 160)         230560
#
#  average_pooling2d_5 (Avera  (None, 2, 2, 160)         0
#  gePooling2D)
#
#  batch_normalization_9 (Bat  (None, 2, 2, 160)         640
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 2, 2, 160)         0
#
#  re_lu_9 (ReLU)              (None, 2, 2, 160)         0
#
#  global_max_pooling2d_1 (Gl  (None, 160)               0
#  obalMaxPooling2D)
#
#  dense_3 (Dense)             (None, 64)                10304
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 557251 (2.13 MB)
# Trainable params: 556035 (2.12 MB)
# Non-trainable params: 1216 (4.75 KB)
# _________________________________________________________________

# %%
model.save("modelExperiment11.keras")

# %%
# Retrieve the configuration of the best hyperparameters
best_hyperparameters = best_hps.get_config()

# Print the best hyperparameters in a readable format
print("Best Hyperparameters:")
for param, value in best_hyperparameters.items():
    print(f"{param}: {value}")
# Out:
# Best Hyperparameters:
# space: [{'class_name': 'Int', 'config': {'name': 'conv_layers', 'default': 3, 'conditions': [], 'min_value': 1, 'max_value': 5, 'step': 1, 'sampling': 'linear'}}, {'class_name': 'Int', 'config': {'name': 'filters_0', 'default': None, 'conditions': [], 'min_value': 32, 'max_value': 160, 'step': 32, 'sampling': 'linear'}}, {'class_name': 'Choice', 'config': {'name': 'kernel_size_0', 'default': 3, 'conditions': [], 'values': [3, 5], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'pooling0', 'default': 'max', 'conditions': [], 'values': ['max', 'avg'], 'ordered': False}}, {'class_name': 'Int', 'config': {'name': 'filters_1', 'default': None, 'conditions': [], 'min_value': 32, 'max_value': 160, 'step': 32, 'sampling': 'linear'}}, {'class_name': 'Choice', 'config': {'name': 'kernel_size_1', 'default': 3, 'conditions': [], 'values': [3, 5], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'pooling1', 'default': 'max', 'conditions': [], 'values': ['max', 'avg'], 'ordered': False}}, {'class_name': 'Int', 'config': {'name': 'filters_2', 'default': None, 'conditions': [], 'min_value': 32, 'max_value': 160, 'step': 32, 'sampling': 'linear'}}, {'class_name': 'Choice', 'config': {'name': 'kernel_size_2', 'default': 3, 'conditions': [], 'values': [3, 5], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'pooling2', 'default': 'max', 'conditions': [], 'values': ['max', 'avg'], 'ordered': False}}, {'class_name': 'Choice', 'config': {'name': 'global_pooling', 'default': 'max', 'conditions': [], 'values': ['max', 'avg'], 'ordered': False}}, {'class_name': 'Choice', 'config': {'name': 'learning_rate', 'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}}, {'class_name': 'Int', 'config': {'name': 'filters_3', 'default': None, 'conditions': [], 'min_value': 32, 'max_value': 160, 'step': 32, 'sampling': 'linear'}}, {'class_name': 'Choice', 'config': {'name': 'kernel_size_3', 'default': 3, 'conditions': [], 'values': [3, 5], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'pooling3', 'default': 'max', 'conditions': [], 'values': ['max', 'avg'], 'ordered': False}}, {'class_name': 'Int', 'config': {'name': 'filters_4', 'default': None, 'conditions': [], 'min_value': 32, 'max_value': 160, 'step': 32, 'sampling': 'linear'}}, {'class_name': 'Choice', 'config': {'name': 'kernel_size_4', 'default': 3, 'conditions': [], 'values': [3, 5], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'pooling4', 'default': 'max', 'conditions': [], 'values': ['max', 'avg'], 'ordered': False}}]
# values: {'conv_layers': 5, 'filters_0': 96, 'kernel_size_0': 5, 'pooling0': 'max', 'filters_1': 32, 'kernel_size_1': 3, 'pooling1': 'avg', 'filters_2': 160, 'kernel_size_2': 3, 'pooling2': 'max', 'global_pooling': 'max', 'learning_rate': 0.01, 'filters_3': 160, 'kernel_size_3': 3, 'pooling3': 'avg', 'filters_4': 160, 'kernel_size_4': 3, 'pooling4': 'avg', 'tuner/epochs': 10, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

loss = history.history["loss"]
val_loss = history.history["val_loss"]

best_epoch = np.argmax(val_acc)

epochs_range = range(len(acc))

plt.figure(figsize=(12, 6))

# Plotting Training and Validation Accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Training Accuracy")
plt.plot(epochs_range, val_acc, label="Validation Accuracy")
plt.scatter(best_epoch, acc[best_epoch], color="red")
plt.scatter(best_epoch, val_acc[best_epoch], color="red", label="Best Epoch")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(loc="lower right")
plt.title("Training and Validation Accuracy")
plt.grid(True)

# Plotting Training and Validation Loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label="Validation Loss")
plt.scatter(best_epoch, loss[best_epoch], color="red")
plt.scatter(best_epoch, val_loss[best_epoch], color="red", label="Best Epoch")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc="upper right")
plt.title("Training and Validation Loss")
plt.grid(True)

plt.suptitle("Training and Validation Metrics", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
print(f"Best Epoch: {best_epoch + 1}")
print(f"Accuracy at Best Epoch: {acc[best_epoch]:.4f}")
print(f"Validation Accuracy at Best Epoch: {val_acc[best_epoch]:.4f}")
print(f"Loss at Best Epoch: {loss[best_epoch]:.4f}")
print(f"Validation Loss at Best Epoch: {val_loss[best_epoch]:.4f}")
# Out:
# Best Epoch: 29
# Accuracy at Best Epoch: 0.5749
# Validation Accuracy at Best Epoch: 0.5533
# Loss at Best Epoch: 0.9046
# Validation Loss at Best Epoch: 1.0194

# %%
img = keras.preprocessing.image.load_img(
    "hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--layered-natural-hair-natural-black-hairstyles.jpg",
    target_size=image_size,
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
print(
    "This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions[0])
)
# Out:
# 1/1 [==============================] - 0s 235ms/step
# This image is 1.00 percent curly hair, 0.00 percent straight hair, and 0.00 percent wavy hair.
