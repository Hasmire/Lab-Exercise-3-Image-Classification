# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import numpy as np

# %%
from pathlib import Path
from PIL import Image
import os

data_dir = "hair_types"
image_extensions = [".png", ".jpg"]

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]

for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        try:
            with Image.open(filepath) as img:
                img_type = img.format.lower()
                if img_type is None:
                    print(f"{filepath} is not an image")
                    os.remove(filepath)
                elif img_type not in img_type_accepted_by_tf:
                    print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
                    os.remove(filepath)

        except (IOError, OSError) as e:
            print(f"Error opening {filepath}: {e}")

# %%
from tensorflow import keras

image_size = (64, 64)
batch_size = 32

class_names = ["Curly_Hair", "Straight_Hair", "Wavy_Hair"]

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels="inferred",
    label_mode="categorical",
    class_names=class_names,
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "hair_types",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    labels="inferred",
    label_mode="categorical",
    class_names=class_names,
)
# Out:
# Found 985 files belonging to 3 classes.
# Using 788 files for training.
# Found 985 files belonging to 3 classes.
# Using 197 files for validation.

# %%
class_names = train_ds.class_names
print("Class names:", class_names)
# Out:
# Class names: ['Curly_Hair', 'Straight_Hair', 'Wavy_Hair']

# %%
import matplotlib.pyplot as plt

for images, labels in train_ds.take(1):
    plt.figure(figsize=(10, 10))
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[tf.argmax(labels[i]).numpy()])
    plt.show()

# %%
data_augmentation = tf.keras.Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical", input_shape=(64, 64, 3)),
        layers.RandomRotation(factor=0.4),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ]
)

# %%
sample_images = train_ds.take(1)
for images, _ in sample_images:
    sample_image = images[0]
    break

# Reshape the image for data augmentation
image = tf.expand_dims(sample_image, 0)
image = tf.cast(image, tf.float32)

plt.figure(figsize=(10, 10))
for i in range(9):
    augmented_image = data_augmentation(image)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(tf.squeeze(augmented_image).numpy().astype("uint8"))

plt.show()

# %%
AUTOTUNE = tf.data.AUTOTUNE


def prepare(ds, shuffle=False, augment=False):
    if shuffle:
        ds = ds.shuffle(1000)

    if augment:
        ds = ds.map(
            lambda x, y: (data_augmentation(x, training=True), y),
            num_parallel_calls=AUTOTUNE,
        )

    # Use buffered prefetching on all datasets.
    return ds.prefetch(buffer_size=AUTOTUNE)

# %%
train_ds = prepare(train_ds)
val_ds = prepare(val_ds)

# %%
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization

model = Sequential(
    [
        # Data Augment and rescaling
        data_augmentation,
        layers.Rescaling(1.0 / 255, input_shape=(64, 64, 3)),
        # Layer 1
        layers.Conv2D(32, kernel_size=3, padding="same", strides=2, activation="relu"),
        layers.Conv2D(64, kernel_size=3, padding="same", strides=2, activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Dropout(0.5),
        # Layer 2
        layers.Conv2D(128, kernel_size=3, padding="same", strides=2, activation="relu"),
        layers.Conv2D(128, kernel_size=3, padding="same", strides=2, activation="relu"),
        layers.MaxPooling2D(),
        layers.Dropout(0.2),
        # Layer 3
        layers.Flatten(),
        layers.Dense(64, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(3, activation="softmax"),
    ]
)

# %%
from tensorflow.keras.optimizers import Adam

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=["accuracy"],
)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor="val_loss", patience=15, restore_best_weights=True, verbose=1
)

# %%
epochs = 100

history = model.fit(
    train_ds,
    epochs=epochs,
    validation_data=val_ds,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/100
# c:\Python311\Lib\site-packages\keras\src\backend.py:5577: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 25/25 [==============================] - 5s 74ms/step - loss: 1.1024 - accuracy: 0.3338 - val_loss: 1.0993 - val_accuracy: 0.2741
# Epoch 2/100
# 25/25 [==============================] - 2s 63ms/step - loss: 1.0989 - accuracy: 0.3528 - val_loss: 1.1016 - val_accuracy: 0.2843
# Epoch 3/100
# 25/25 [==============================] - 2s 63ms/step - loss: 1.0982 - accuracy: 0.3477 - val_loss: 1.1005 - val_accuracy: 0.2843
# Epoch 4/100
# 25/25 [==============================] - 2s 63ms/step - loss: 1.0991 - accuracy: 0.3464 - val_loss: 1.1011 - val_accuracy: 0.2843
# Epoch 5/100
# 25/25 [==============================] - 2s 64ms/step - loss: 1.0969 - accuracy: 0.3528 - val_loss: 1.0999 - val_accuracy: 0.2843
# Epoch 6/100
# 25/25 [==============================] - 2s 67ms/step - loss: 1.0929 - accuracy: 0.3718 - val_loss: 1.0797 - val_accuracy: 0.3807
# Epoch 7/100
# 25/25 [==============================] - 2s 69ms/step - loss: 1.0759 - accuracy: 0.4264 - val_loss: 1.1180 - val_accuracy: 0.3553
# Epoch 8/100
# 25/25 [==============================] - 2s 62ms/step - loss: 1.0706 - accuracy: 0.4264 - val_loss: 1.0641 - val_accuracy: 0.3756
# Epoch 9/100
# 25/25 [==============================] - 2s 64ms/step - loss: 1.0327 - accuracy: 0.4734 - val_loss: 1.0415 - val_accuracy: 0.4518
# Epoch 10/100
# 25/25 [==============================] - 2s 64ms/step - loss: 1.0157 - accuracy: 0.4810 - val_loss: 1.1138 - val_accuracy: 0.3401
# Epoch 11/100
# 25/25 [==============================] - 2s 71ms/step - loss: 1.0030 - accuracy: 0.4784 - val_loss: 1.0367 - val_accuracy: 0.4467
# Epoch 12/100
# 25/25 [==============================] - 2s 63ms/step - loss: 0.9978 - accuracy: 0.4772 - val_loss: 1.0306 - val_accuracy: 0.4822
# Epoch 13/100
# 25/25 [==============================] - 2s 64ms/step - loss: 1.0206 - accuracy: 0.4619 - val_loss: 1.0553 - val_accuracy: 0.4162
# Epoch 14/100
# 25/25 [==============================] - 2s 65ms/step - loss: 0.9892 - accuracy: 0.5102 - val_loss: 1.1344 - val_accuracy: 0.3909
# Epoch 15/100
# 25/25 [==============================] - 2s 65ms/step - loss: 0.9775 - accuracy: 0.5102 - val_loss: 1.0344 - val_accuracy: 0.4670
# Epoch 16/100
# 25/25 [==============================] - 2s 64ms/step - loss: 0.9597 - accuracy: 0.5152 - val_loss: 1.0329 - val_accuracy: 0.4518
# Epoch 17/100
# 25/25 [==============================] - 2s 66ms/step - loss: 0.9482 - accuracy: 0.5393 - val_loss: 1.0328 - val_accuracy: 0.5025
# Epoch 18/100
# 25/25 [==============================] - 2s 64ms/step - loss: 0.9940 - accuracy: 0.5279 - val_loss: 1.0113 - val_accuracy: 0.4924
# Epoch 19/100
# 25/25 [==============================] - 2s 62ms/step - loss: 0.9513 - accuracy: 0.5343 - val_loss: 1.0149 - val_accuracy: 0.4619
# Epoch 20/100
# 25/25 [==============================] - 2s 65ms/step - loss: 0.9702 - accuracy: 0.5140 - val_loss: 1.0003 - val_accuracy: 0.4975
# Epoch 21/100
# 25/25 [==============================] - 2s 71ms/step - loss: 0.9533 - accuracy: 0.5203 - val_loss: 1.0766 - val_accuracy: 0.4569
# Epoch 22/100
# 25/25 [==============================] - 2s 64ms/step - loss: 0.9509 - accuracy: 0.5343 - val_loss: 1.0106 - val_accuracy: 0.4924
# Epoch 23/100
# 25/25 [==============================] - 2s 63ms/step - loss: 0.9287 - accuracy: 0.5533 - val_loss: 1.1255 - val_accuracy: 0.3909
# Epoch 24/100
# 25/25 [==============================] - 2s 67ms/step - loss: 0.9498 - accuracy: 0.5330 - val_loss: 1.0140 - val_accuracy: 0.5076
# Epoch 25/100
# 25/25 [==============================] - 2s 65ms/step - loss: 0.9288 - accuracy: 0.5508 - val_loss: 1.0401 - val_accuracy: 0.4924
# Epoch 26/100
# 25/25 [==============================] - 2s 66ms/step - loss: 0.9002 - accuracy: 0.5685 - val_loss: 1.0616 - val_accuracy: 0.4518
# Epoch 27/100
# 25/25 [==============================] - 2s 66ms/step - loss: 0.9402 - accuracy: 0.5571 - val_loss: 1.0449 - val_accuracy: 0.4315
# Epoch 28/100
# 25/25 [==============================] - 2s 61ms/step - loss: 0.8931 - accuracy: 0.6003 - val_loss: 0.9926 - val_accuracy: 0.5127
# Epoch 29/100
# 25/25 [==============================] - 2s 62ms/step - loss: 0.9007 - accuracy: 0.5901 - val_loss: 1.0114 - val_accuracy: 0.5178
# Epoch 30/100
# 25/25 [==============================] - 2s 61ms/step - loss: 0.9107 - accuracy: 0.5711 - val_loss: 1.0128 - val_accuracy: 0.4873
# Epoch 31/100
# 25/25 [==============================] - 2s 63ms/step - loss: 0.8988 - accuracy: 0.5736 - val_loss: 1.0052 - val_accuracy: 0.5381
# Epoch 32/100
# 25/25 [==============================] - 2s 60ms/step - loss: 0.8978 - accuracy: 0.5926 - val_loss: 0.9946 - val_accuracy: 0.5431
# Epoch 33/100
# 25/25 [==============================] - 2s 60ms/step - loss: 0.8937 - accuracy: 0.5736 - val_loss: 0.9963 - val_accuracy: 0.5330
# Epoch 34/100
# 25/25 [==============================] - 2s 61ms/step - loss: 0.8906 - accuracy: 0.5749 - val_loss: 1.0183 - val_accuracy: 0.4975
# Epoch 35/100
# 25/25 [==============================] - 2s 67ms/step - loss: 0.8825 - accuracy: 0.5812 - val_loss: 0.9918 - val_accuracy: 0.4924
# Epoch 36/100
# 25/25 [==============================] - 2s 67ms/step - loss: 0.8764 - accuracy: 0.5825 - val_loss: 0.9994 - val_accuracy: 0.4873
# Epoch 37/100
# 25/25 [==============================] - 2s 64ms/step - loss: 0.8670 - accuracy: 0.5977 - val_loss: 1.0220 - val_accuracy: 0.4873
# Epoch 38/100
# 25/25 [==============================] - 2s 74ms/step - loss: 0.8702 - accuracy: 0.6053 - val_loss: 1.0297 - val_accuracy: 0.4822
# Epoch 39/100
# 25/25 [==============================] - 3s 74ms/step - loss: 0.8639 - accuracy: 0.5977 - val_loss: 0.9870 - val_accuracy: 0.5228
# Epoch 40/100
# 25/25 [==============================] - 2s 64ms/step - loss: 0.8614 - accuracy: 0.6117 - val_loss: 1.0231 - val_accuracy: 0.5431
# Epoch 41/100
# 25/25 [==============================] - 2s 63ms/step - loss: 0.8606 - accuracy: 0.5914 - val_loss: 1.0210 - val_accuracy: 0.4569
# Epoch 42/100
# 25/25 [==============================] - 2s 71ms/step - loss: 0.8544 - accuracy: 0.5952 - val_loss: 1.0024 - val_accuracy: 0.4975
# Epoch 43/100
# 25/25 [==============================] - 2s 66ms/step - loss: 0.8733 - accuracy: 0.5901 - val_loss: 0.9620 - val_accuracy: 0.5431
# Epoch 44/100
# 25/25 [==============================] - 2s 66ms/step - loss: 0.8501 - accuracy: 0.6193 - val_loss: 1.0165 - val_accuracy: 0.5482
# Epoch 45/100
# 25/25 [==============================] - 2s 64ms/step - loss: 0.8637 - accuracy: 0.6015 - val_loss: 1.0291 - val_accuracy: 0.4924
# Epoch 46/100
# 25/25 [==============================] - 2s 68ms/step - loss: 0.8535 - accuracy: 0.6104 - val_loss: 0.9680 - val_accuracy: 0.5431
# Epoch 47/100
# 25/25 [==============================] - 2s 72ms/step - loss: 0.8495 - accuracy: 0.6015 - val_loss: 1.0380 - val_accuracy: 0.4467
# Epoch 48/100
# 25/25 [==============================] - 2s 65ms/step - loss: 0.8304 - accuracy: 0.6066 - val_loss: 0.9742 - val_accuracy: 0.5381
# Epoch 49/100
# 25/25 [==============================] - 2s 65ms/step - loss: 0.8050 - accuracy: 0.6231 - val_loss: 1.0577 - val_accuracy: 0.4772
# Epoch 50/100
# 25/25 [==============================] - 2s 62ms/step - loss: 0.8445 - accuracy: 0.6117 - val_loss: 1.0171 - val_accuracy: 0.5178
# Epoch 51/100
# 25/25 [==============================] - 2s 62ms/step - loss: 0.8224 - accuracy: 0.6117 - val_loss: 1.0377 - val_accuracy: 0.4873
# Epoch 52/100
# 25/25 [==============================] - 2s 71ms/step - loss: 0.8159 - accuracy: 0.6510 - val_loss: 1.0212 - val_accuracy: 0.5178
# Epoch 53/100
# 25/25 [==============================] - 3s 74ms/step - loss: 0.8373 - accuracy: 0.6180 - val_loss: 1.0267 - val_accuracy: 0.5178
# Epoch 54/100
# 25/25 [==============================] - 2s 70ms/step - loss: 0.8313 - accuracy: 0.5964 - val_loss: 1.0185 - val_accuracy: 0.4822
# Epoch 55/100
# 25/25 [==============================] - 3s 76ms/step - loss: 0.8127 - accuracy: 0.6117 - val_loss: 1.0332 - val_accuracy: 0.4975
# Epoch 56/100
# 25/25 [==============================] - 2s 69ms/step - loss: 0.8087 - accuracy: 0.6345 - val_loss: 1.0433 - val_accuracy: 0.4772
# Epoch 57/100
# 25/25 [==============================] - 2s 65ms/step - loss: 0.8112 - accuracy: 0.6142 - val_loss: 1.0162 - val_accuracy: 0.4924
# Epoch 58/100
# 25/25 [==============================] - ETA: 0s - loss: 0.8087 - accuracy: 0.6269Restoring model weights from the end of the best epoch: 43.
# 25/25 [==============================] - 3s 75ms/step - loss: 0.8087 - accuracy: 0.6269 - val_loss: 1.1013 - val_accuracy: 0.5279
# Epoch 58: early stopping

# %%
tf.keras.utils.plot_model(model, to_file="model_experiment7.png", show_shapes=True)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 64, 64, 3)         0
#
#  rescaling (Rescaling)       (None, 64, 64, 3)         0
#
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d (MaxPooling2  (None, 8, 8, 64)          0
#  D)
#
#  dropout (Dropout)           (None, 8, 8, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         73856
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 128)         147584
#
#  max_pooling2d_1 (MaxPoolin  (None, 1, 1, 128)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 251267 (981.51 KB)
# Trainable params: 251267 (981.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

loss = history.history["loss"]
val_loss = history.history["val_loss"]

best_epoch = np.argmin(val_loss)

epochs_range = range(len(acc))

plt.figure(figsize=(12, 6))

# Plotting Training and Validation Accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Training Accuracy")
plt.plot(epochs_range, val_acc, label="Validation Accuracy")
plt.scatter(best_epoch, acc[best_epoch], color="red")
plt.scatter(best_epoch, val_acc[best_epoch], color="red", label="Best Epoch")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(loc="lower right")
plt.title("Training and Validation Accuracy")
plt.grid(True)

# Plotting Training and Validation Loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label="Validation Loss")
plt.scatter(best_epoch, loss[best_epoch], color="red")
plt.scatter(best_epoch, val_loss[best_epoch], color="red", label="Best Epoch")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc="upper right")
plt.title("Training and Validation Loss")
plt.grid(True)

plt.suptitle("Training and Validation Metrics", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]

loss = history.history["loss"]
val_loss = history.history["val_loss"]

best_epoch = np.argmin(val_loss)

epochs_range = range(len(acc))

plt.figure(figsize=(12, 6))

# Plotting Training and Validation Accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Training Accuracy")
plt.plot(epochs_range, val_acc, label="Validation Accuracy")
plt.scatter(best_epoch, acc[best_epoch], color="red")
plt.scatter(best_epoch, val_acc[best_epoch], color="red", label="Best Epoch")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(loc="lower right")
plt.title("Training and Validation Accuracy")
plt.grid(True)

# Plotting Training and Validation Loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label="Validation Loss")
plt.scatter(best_epoch, loss[best_epoch], color="red")
plt.scatter(best_epoch, val_loss[best_epoch], color="red", label="Best Epoch")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc="upper right")
plt.title("Training and Validation Loss")
plt.grid(True)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
print(f"Best Epoch: {best_epoch + 1}")
print(f"Accuracy at Best Epoch: {acc[best_epoch]:.4f}")
print(f"Validation Accuracy at Best Epoch: {val_acc[best_epoch]:.4f}")
print(f"Loss at Best Epoch: {loss[best_epoch]:.4f}")
print(f"Validation Loss at Best Epoch: {val_loss[best_epoch]:.4f}")
# Out:
# Best Epoch: 43
# Accuracy at Best Epoch: 0.5901
# Validation Accuracy at Best Epoch: 0.5431
# Loss at Best Epoch: 0.8733
# Validation Loss at Best Epoch: 0.9620

# %%
img = keras.preprocessing.image.load_img(
    "hair_types/Curly_Hair/02dac897d1dec9ba8c057a11d041ada8--layered-natural-hair-natural-black-hairstyles.jpg",
    target_size=image_size,
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
print(
    "This image is %.2f percent curly hair, %.2f percent straight hair, and %.2f percent wavy hair."
    % tuple(predictions[0])
)
# Out:
# 1/1 [==============================] - 0s 240ms/step
# This image is 0.73 percent curly hair, 0.18 percent straight hair, and 0.09 percent wavy hair.
